# %%
# !ls /usr/bin
# Out:
# '['			       man
#  addr2line		       mandb
#  alias			       manpath
#  apropos		       mariadb_config
#  ar			       mcookie
#  arch			       md5sum
#  as			       mesg
#  aserver		       microdnf
#  autoconf		       mkdir
#  autoheader		       mkfifo
#  autom4te		       mkfontdir
#  autoreconf		       mkfontscale
#  autoscan		       mknod
#  autoupdate		       mktemp
#  awk			       modulemd-validator
#  b2sum			       more
#  base32			       mount
#  base64			       mountpoint
#  basename		       mv
#  bash			       mysql_config
#  bashbug		       namei
#  bashbug-64		       nano
#  bdftopcf		       nc
#  bg			       ncat
#  brotli			       neqn
#  bunzip2		       newgidmap
#  bzcat			       newgrp
#  bzcmp			       newuidmap
#  bzdiff			       nice
#  bzegrep		       nisdomainname
#  bzfgrep		       nl
#  bzgrep			       nm
#  bzip2			       nohup
#  bzip2recover		       nproc
#  bzless			       nroff
#  bzmore			       nsenter
#  c++			       numfmt
#  c89			       objcopy
#  c99			       objdump
#  cairo-sphinx		       od
#  cal			       openssl
#  ca-legacy		       p11-kit
#  captoinfo		       pango-list
#  cat			       pango-view
#  catchsegv		       paste
#  catman			       pathchk
#  cc			       pcre2-config
#  cd			       peekfd
#  c++filt		       perl
#  chage			       perl5.26.3
#  chcon			       perldoc
#  checksctp		       pg_config
#  chgrp			       pgrep
#  chmem			       pic
#  chmod			       piconv
#  chown			       pidof
#  chrt			       pkgconf
#  cksum			       pkg-config
#  clear			       pkill
#  cmp			       pldd
#  col			       pmap
#  colcrt			       pod2man
#  colrm			       pod2text
#  column			       pod2usage
#  comm			       post-grohtml
#  command		       pr
#  compile_et		       preconv
#  coreutils		       pre-grohtml
#  cp			       printenv
#  cpp			       printf
#  csplit			       prlimit
#  curl			       prtstat
#  cut			       ps
#  date			       pslog
#  db_archive		       pstree
#  db_checkpoint		       pstree.x11
#  db_deadlock		       ptx
#  db_dump		       pwd
#  db_dump185		       pwdx
#  db_hotbackup		       pwmake
#  db_load		       pwscore
#  db_log_verify		       pydoc3.6
#  db_printlog		       pyvenv-3.6
#  db_recover		       ranlib
#  db_replicate		       raw
#  db_stat		       read
#  db_tuner		       readelf
#  db_upgrade		       readlink
#  db_verify		       realpath
#  dd			       rename
#  df			       renew-dummy-cert
#  diff			       renice
#  diff3			       reset
#  dir			       rev
#  dircolors		       rm
#  dirmngr		       rmdir
#  dirmngr-client		       rnano
#  dirname		       rpm
#  dmesg			       rpm2archive
#  dnsdomainname		       rpm2cpio
#  domainname		       rpmdb
#  du			       rpmkeys
#  dwp			       rpmquery
#  echo			       rpmverify
#  egrep			       runcon
#  eject			       rvi
#  elfedit		       rview
#  encguess		       scp
#  env			       script
#  eqn			       scriptreplay
#  ex			       sctp_darn
#  expand			       sctp_status
#  expr			       sctp_test
#  factor			       sdiff
#  fallocate		       sed
#  false			       seq
#  fc			       setarch
#  fc-cache		       setpriv
#  fc-cache-64		       setsid
#  fc-cat			       setterm
#  fc-conflist		       setup-nsssysinit
#  fc-list		       setup-nsssysinit.sh
#  fc-match		       sftp
#  fc-pattern		       sg
#  fc-query		       sh
#  fc-scan		       sha1sum
#  fc-validate		       sha224sum
#  fg			       sha256sum
#  fgrep			       sha384sum
#  fincore		       sha512sum
#  find			       shred
#  findmnt		       shuf
#  fips-finish-install	       sim_client
#  fips-mode-setup	       size
#  flock			       skill
#  fmt			       slabtop
#  fold			       sleep
#  fonttosfnt		       snice
#  free			       soelim
#  fribidi		       sort
#  funzip			       sotruss
#  g++			       split
#  g13			       sprof
#  gapplication		       ssh
#  gawk			       ssh-add
#  gcc			       ssh-agent
#  gcc-ar			       ssh-copy-id
#  gcc-nm			       ssh-keygen
#  gcc-ranlib		       ssh-keyscan
#  gcov			       stat
#  gcov-dump		       stdbuf
#  gcov-tool		       strings
#  gdbm_dump		       strip
#  gdbm_load		       stty
#  gdbmtool		       su
#  gdbus			       sum
#  gdk-pixbuf-query-loaders-64   sync
#  gdk-pixbuf-thumbnailer        tabs
#  gencat			       tac
#  geqn			       tail
#  getconf		       tar
#  getent			       taskset
#  getopt			       tbl
#  getopts		       tee
#  gio			       test
#  gio-querymodules-64	       tic
#  git			       timeout
#  git-receive-pack	       tload
#  git-shell		       toe
#  git-upload-archive	       top
#  git-upload-pack	       touch
#  glib-compile-schemas	       tput
#  gmake			       tr
#  gneqn			       troff
#  gnroff			       true
#  gpasswd		       truncate
#  gpg			       trust
#  gpg2			       tset
#  gpg-agent		       tsort
#  gpgconf		       ttmkfdir
#  gpg-connect-agent	       tty
#  gpg-error		       type
#  gpgme-json		       tzselect
#  gpgparsemail		       ucs2any
#  gpgsplit		       ul
#  gpgv			       ulimit
#  gpgv2			       umask
#  gpg-wks-server		       umount
#  gpg-zip		       unalias
#  gpic			       uname
#  gprof			       uname26
#  gr2fonttest		       unexpand
#  grep			       uniq
#  groff			       unlink
#  grops			       unshare
#  grotty			       unversioned-python
#  groups			       unxz
#  gsettings		       unzip
#  gsoelim		       unzipsfx
#  gss-client		       update-ca-trust
#  gtar			       update-crypto-policies
#  gtbl			       update-gtk-immodules
#  gtk-query-immodules-2.0-64    update-mime-database
#  gtk-update-icon-cache	       uptime
#  gtroff			       users
#  gunzip			       utmpdump
#  gzexe			       uuclient
#  gzip			       uuidgen
#  hash			       uuidparse
#  head			       vdir
#  hexdump		       vi
#  hostid			       view
#  hostname		       vmstat
#  i386			       w
#  iconv			       wait
#  id			       wall
#  ifnames		       watch
#  info			       watchgnupg
#  infocmp		       wc
#  infotocap		       wdctl
#  install		       wget
#  ionice			       whatis
#  ipcmk			       whereis
#  ipcrm			       which
#  ipcs			       who
#  isosize		       whoami
#  java			       withsctp
#  javac			       write
#  jobs			       x86_64
#  join			       x86_64-redhat-linux-c++
#  kill			       x86_64-redhat-linux-g++
#  killall		       x86_64-redhat-linux-gcc
#  krb5-config		       x86_64-redhat-linux-gcc-8
#  last			       x86_64-redhat-linux-gnu-pkg-config
#  lastb			       xargs
#  lastlog		       xmlcatalog
#  ld			       xmllint
#  ld.bfd			       xmlwf
#  ldd			       xorg-x11-fonts-update-dirs
#  ld.gold		       xz
#  less			       xzcat
#  lessecho		       xzcmp
#  lesskey		       xzdec
#  lesspipe.sh		       xzdiff
#  lexgrog		       xzegrep
#  link			       xzfgrep
#  linux32		       xzgrep
#  linux64		       xzless
#  ln			       xzmore
#  locale			       yes
#  localedef		       ypdomainname
#  logger			       zcat
#  login			       zcmp
#  logname		       zdiff
#  look			       zegrep
#  ls			       zfgrep
#  lsblk			       zforce
#  lscpu			       zgrep
#  lsipc			       zip
#  lslocks		       zipcloak
#  lslogins		       zipgrep
#  lsmem			       zipinfo
#  lsns			       zipnote
#  lua			       zipsplit
#  luac			       zless
#  m4			       zmore
#  make			       znew
#  makedb			       zsoelim
#  make-dummy-cert

# %%
import requests
from lxml.etree import HTML

# %%
url = 'https://vc.sharif.edu/ch/bastanih'

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
uuu = 'https://president.gov.af/da/'
response = requests.get(url, headers=headers)
root = HTML(response.content)

# %%
a = root.xpath('//button[@id="btn_guest"]')[0]

# %%
# !dnf install https://dl.fedoraproject.org/pub/epel/epel-release-latest-8.noarch.rpm
# !dnf upgrade
# Out:
# /usr/bin/sh: dnf: command not found
# /usr/bin/sh: dnf: command not found

# %%
# !rpm -ivh https://dl.fedoraproject.org/pub/epel/epel-release-latest-7.noarch.rpm
# Out:
# Retrieving https://dl.fedoraproject.org/pub/epel/epel-release-latest-7.noarch.rpm
# warning: /var/tmp/rpm-tmp.bKqOE8: Header V4 RSA/SHA256 Signature, key ID 352c64e5: NOKEY
# error: can't create transaction lock on /var/lib/rpm/.rpm.lock (Permission denied)

# %%
# !cat /etc/os-release
# Out:
# NAME="Red Hat Enterprise Linux"
# VERSION="8.3 (Ootpa)"
# ID="rhel"
# ID_LIKE="fedora"
# VERSION_ID="8.3"
# PLATFORM_ID="platform:el8"
# PRETTY_NAME="Red Hat Enterprise Linux 8.3 (Ootpa)"
# ANSI_COLOR="0;31"
# CPE_NAME="cpe:/o:redhat:enterprise_linux:8.3:GA"
# HOME_URL="https://www.redhat.com/"
# BUG_REPORT_URL="https://bugzilla.redhat.com/"
#
# REDHAT_BUGZILLA_PRODUCT="Red Hat Enterprise Linux 8"
# REDHAT_BUGZILLA_PRODUCT_VERSION=8.3
# REDHAT_SUPPORT_PRODUCT="Red Hat Enterprise Linux"
# REDHAT_SUPPORT_PRODUCT_VERSION="8.3"
